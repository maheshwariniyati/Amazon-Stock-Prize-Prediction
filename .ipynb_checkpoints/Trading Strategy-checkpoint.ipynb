# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss

df = pd.read_csv("RF.csv")
T=df['Y_rf'].shape[0]

Y_rf = np.asarray(df['Y_rf'])
Y = np.asarray(df['Y'])
Y_close = np.asarray(df['Y_close'])

# %%
df.head()
# Out:
#         Y        Y_rf  Y_close
# 0  852.52  851.936496   852.69
# 1  852.96  852.672856   856.70
# 2  859.00  857.201191   841.80
# 3  839.50  847.289339   848.30
# 4  848.11  844.518777   847.75

# %% [markdown]
# #### Rule1: Day Trading

# %%
signal_rule1 =  np.zeros(T)
for t in range(0, T):
    if Y_rf[t] > Y[t]:
        signal_rule1[t] = 1  # long signal
    elif Y_rf[t] < Y[t]:
        signal_rule1[t] = -1  # short signal
        
pos_rule1 = signal_rule1 # open and close position every day

# %% [markdown]
# **Rule2: Long Short**

# %%
"trading rule 2: long short"
signal_rule2 = np.zeros(T)
pos_rule2 = np.zeros(T)
for t in range(0, T):
    if Y_rf[t] > Y[t]:
        signal_rule2[t] = 1  
    elif Y_rf[t] < Y[t]:
        signal_rule2[t] = -1  

for t in range(0, T):
    if t==0:
        pos_rule2[t] = signal_rule2[t]
    elif signal_rule2[t] != signal_rule2[t-1]: 
        # take the first long/short signal as position
        pos_rule2[t] = signal_rule2[t]

# %% [markdown]
# **Rule 3:**

# %%
"trading rule 3: buy hold"
signal_rule3 =  np.zeros(T)
pos_rule3 = np.zeros(T)
for t in range(0, T):
    if t==0:
        signal_rule3[t] = 1  
    else:
        signal_rule3[t] =  -1

pos_rule3 = signal_rule3

# %% [markdown]
# #### Backtesting

# %%
"account balances"

init_bal = 1000000 #initial account balance
num_shares = 600 # number of shares being traded in one position


balance_rule1= np.zeros(T)
balance_rule2= np.zeros(T)
balance_rule3= np.zeros(T)

temp_bal1 = init_bal
temp_bal2 = init_bal
temp_bal3 = init_bal
for t in range(0,T):  
    # day trade
    balance_rule1[t] = temp_bal1 - pos_rule1[t]*num_shares*Y[t] + pos_rule1[t]*num_shares*Y_close[t]
    temp_bal1 = balance_rule1[t]
    
    # long short
    balance_rule2[t] = temp_bal2 - pos_rule2[t]*num_shares*Y[t] + pos_rule2[t]*num_shares*Y_close[t]
    temp_bal2 = balance_rule2[t]  
    # buy hold
    if t==0:
        # initially hold long position and not close it
        balance_rule3[t] = temp_bal3 - pos_rule3[t]*num_shares*Y[t]  
        temp_bal3 = balance_rule3[t]
    else:
        # closing initial position at time t, aka holdig it for t-1 days
        balance_rule3[t] = temp_bal3 + pos_rule3[0]*num_shares*Y_close[t] 

    
    
# plot account balance
timevec = np.linspace(1,T-1,T-1)
plt.figure(figsize=(30,20))

ax1 = plt.subplot(211)
ax1.plot(timevec, balance_rule1[1:], 'blue', label = "Day Trade")
ax1.plot(timevec, balance_rule2[1:], 'red', label = "Long Short")
ax1.plot(timevec, balance_rule3[1:], 'green', label = "Buy Hold")
ax1.legend(loc=2, bbox_to_anchor=(0.5, 1.00), shadow=True, ncol=2)
plt.title('Trading Strategy Performance - Amazon')
plt.show()

# %%
combined = np.stack([Y, Y_rf, signal_rule1, pos_rule1, balance_rule1, 
                     signal_rule2, pos_rule2, balance_rule2,   
                     signal_rule3, pos_rule3, balance_rule3,Y_close], axis = 1)
df1 = pd.DataFrame(combined, index=np.arange(0,T), 
                  columns=['Y','Y_RF','sig_1','pos_1','bal_1',
                           'sig_2','pos_2','bal_2',
                           'sig_3','pos_3','bal_3','Y_close'])

df1['PL1'] = df1.bal_1 - df1.bal_1.shift(1)
df1['PL2'] = df1.bal_2 - df1.bal_2.shift(1)
df1['PL3'] = df1.bal_3 - df1.bal_3.shift(1)

df1['PL1'][0] = df1['bal_1'][0] - 1000000 
df1['PL2'][0] = df1['bal_2'][0] - 1000000
df1['PL3'][0] = df1['bal_3'][0] - 1000000

df1.to_csv('trades.csv')

# %%
df1.head()
# Out:
#         Y        Y_RF  sig_1  pos_1      bal_1  sig_2  pos_2      bal_2  \
# 0  852.52  851.936496   -1.0   -1.0   999898.0   -1.0   -1.0   999898.0
# 1  852.96  852.672856   -1.0   -1.0   997654.0   -1.0    0.0   999898.0
# 2  859.00  857.201191   -1.0   -1.0  1007974.0   -1.0    0.0   999898.0
# 3  839.50  847.289339    1.0    1.0  1013254.0    1.0    1.0  1005178.0
# 4  848.11  844.518777   -1.0   -1.0  1013470.0   -1.0   -1.0  1005394.0
#
#    sig_3  pos_3      bal_3  Y_close      PL1     PL2       PL3
# 0    1.0    1.0   488488.0   852.69   -102.0  -102.0 -511512.0
# 1   -1.0   -1.0  1002508.0   856.70  -2244.0     0.0  514020.0
# 2   -1.0   -1.0   993568.0   841.80  10320.0     0.0   -8940.0
# 3   -1.0   -1.0   997468.0   848.30   5280.0  5280.0    3900.0
# 4   -1.0   -1.0   997138.0   847.75    216.0   216.0    -330.0

# %%
"analytics: profit and loss, ratios, etc"

# daily profit and loss
profit_loss1 =  df1.PL1.sum()

profit_loss2 =  df1.PL2.sum()

profit_loss3 =  df1.PL3.sum()


balance_rule1 = np.insert(balance_rule1, 0, init_bal)

balance_rule2 = np.insert(balance_rule2, 0, init_bal)

balance_rule3 = np.insert(balance_rule3, 0, init_bal)

total_profit1 = sum(x for x in df1.PL1 if x>0)    
total_loss1 = abs(sum(x for x in df1.PL1 if x<0))

cnt_profit1 = 0
cnt_loss1 = 0
for num in df1.PL1: 
    if num >= 0: 
        cnt_profit1 += 1
    else: 
        cnt_loss1 += 1
        

total_profit2 = sum(x for x in df1.PL2 if x>0)    
total_loss2 = abs(sum(x for x in df1.PL2 if x<0))

cnt_profit2 = 0
cnt_loss2 = 0
for num in df1.PL2: 
    if num >= 0: 
        cnt_profit2 += 1
    else: 
        cnt_loss2 += 1


total_profit3 = sum(x for x in df1.PL3 if x>0)    
total_loss3 = abs(sum(x for x in df1.PL3 if x<0))
cnt_profit3 = 0
cnt_loss3 = 0
for num in df1.PL3: 
    if num >= 0: 
        cnt_profit3 += 1
    else: 
        cnt_loss3 += 1


# daily return in percentage
return1 = (balance_rule1 - init_bal)/init_bal*100
return2 = (balance_rule2 - init_bal)/init_bal*100
return3 = (balance_rule3 - init_bal)/init_bal*100


# ratios, assuming 3 month T bill rate around 2%
sharpe1 = (np.mean(return1) - 2)/np.std(return1-2)
sharpe2 = (np.mean(return2) - 2)/np.std(return2-2)
sharpe3 = (np.mean(return3) - 2)/np.std(return3-2)
sortino1 =(np.mean(return1) - 2)/np.std([x for x in return1 if x<0])
sortino2 =(np.mean(return2) - 2)/np.std([x for x in return2 if x<0])
sortino3 =(np.mean(return3) - 2)/np.std([x for x in return3 if x<0])

# %%
print("*************************DAY TRADE Results***************************")
print("Trading Days: ",T)      
print("Total Profit: ", total_profit1, "\n total loss: ", total_loss1, "\n Profit%: ", (profit_loss1/init_bal)*100)
print("Number of Profit Days: ", cnt_profit1, "\n Number of Loss Days: ", cnt_loss1)
print("Average net-profit per trade: ", (total_profit1-total_loss1)/T)
print("Average daily return: ", np.mean(return1))
print("Daily return std: ", np.std(return1))
print("Daily return skewness: ", ss.skew(return1))
print("Daily return kurtosis: ", ss.kurtosis(return1))
print("Sharpe ratio: ", sharpe1)

den = ss.gaussian_kde(return1) 
xs = np.linspace(-3,3,400)
plt.plot(xs,den(xs))
plt.show()
# Out:
# *************************DAY TRADE Results***************************
# Trading Days:  368
# Total Profit:  1537158.0
#  total loss:  1585992.0
#  Profit%:  -4.883400000000047
# Number of Profit Days:  180
#  Number of Loss Days:  188
# Average net-profit per trade:  -132.70108695652175
# Average daily return:  -0.6082569105691124
# Daily return std:  3.5838855617908916
# Daily return skewness:  -0.2418087843771333
# Daily return kurtosis:  0.005542986974552022
# Sharpe ratio:  -0.7277734920938014

# %%
print("*************************LONG SHORT Results***************************")
print("Trading Days: ",T)      
print("Total Profit: ", total_profit2, "\n Total Loss:", total_loss2, "\n Profit%: ", (profit_loss2/init_bal)*100)
print("Number of Profit Days: ", cnt_profit2, "\n Number of Loss Days: ", cnt_loss2)
print("Average net-profit per trade: ", (total_profit2-total_loss2)/T)
print("Average daily return: ", np.mean(return2))
print("Daily return std: ", np.std(return2))
print("Daily return skewness: ", ss.skew(return2))
print("Daily return kurtosis: ", ss.kurtosis(return2))
print("Sharpe ratio: ", sharpe2)

den = ss.gaussian_kde(return2) 
xs = np.linspace(-3,3,400)
plt.plot(xs,den(xs))
plt.show()
# Out:
# *************************LONG SHORT Results***************************
# Trading Days:  368
# Total Profit:  638237.9999999999
#  Total Loss: 818063.9999999999
#  Profit%:  -17.9826
# Number of Profit Days:  276
#  Number of Loss Days:  92
# Average net-profit per trade:  -488.6576086956522
# Average daily return:  -4.507656910569105
# Daily return std:  5.226300961437776
# Daily return skewness:  -1.1853168496364082
# Daily return kurtosis:  0.27194184740424543
# Sharpe ratio:  -1.2451745428718715

# %%
print("*************************BUY HOLD Results***************************")
print("Number of trading days: ",T)      
print("Total profit: ", total_profit3, "\nTotal loss:", total_loss3, "\nProfit%: ", (profit_loss3/init_bal)*100)
print("Number of Profit Days: ", cnt_profit3, "\nNumber of Loss Days: ", cnt_loss3)
print("Average net-profit per trade: ", (total_profit3-total_loss3)/T)
print("Average daily return: ", np.mean(return3))
print("Daily return std: ", np.std(return3))
print("Daily return skewness: ", ss.skew(return3))
print("Daily return kurtosis: ", ss.kurtosis(return3))
print("Sharpe ratio: ", sharpe3)

den = ss.gaussian_kde(return3) 
xs = np.linspace(-1,6,400)
plt.plot(xs,den(xs))
plt.show()
# Out:
# *************************BUY HOLD Results***************************
# Number of trading days:  368
# Total profit:  2460432.0
# Total loss: 1770654.0
# Profit%:  68.9778
# Number of Profit Days:  214
# Number of Loss Days:  154
# Average net-profit per trade:  1874.3967391304348
# Average daily return:  25.120252032520323
# Daily return std:  20.025896928099215
# Daily return skewness:  0.3329573540532869
# Daily return kurtosis:  -0.7328433482450061
# Sharpe ratio:  1.1545176785604685
